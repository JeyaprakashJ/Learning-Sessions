# %% [markdown]
# ### Group by and Aggregating

# %%
import pandas as pd

# %%
df_base = pd.read_csv('/Users/Z00CVY1/Documents/Python Tutorials/demo files/zpopulation.csv')
df_base
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df = df_base[['Country', 'Continent','2022 Population']].copy()

# %%
df
# Out:
#                Country Continent  2022 Population
# 0          Afghanistan      Asia       41128771.0
# 1              Albania    Europe        2842321.0
# 2              Algeria    Africa       44903225.0
# 3       American Samoa   Oceania          44273.0
# 4              Andorra    Europe          79824.0
# ..                 ...       ...              ...
# 229  Wallis and Futuna   Oceania          11572.0
# 230     Western Sahara    Africa         575986.0
# 231              Yemen      Asia       33696614.0
# 232             Zambia    Africa       20017675.0
# 233           Zimbabwe    Africa       16320537.0
#
# [234 rows x 3 columns]

# %%
df.columns

# %%
df.rename(columns={'2022 Population': '2022_Population'}, inplace=True)

# %%
# df['2022_Population'] = df['2022_Population'] //10

# %%
df
# Out:
#                Country Continent  2022_Population
# 0          Afghanistan      Asia         411287.0
# 1              Albania    Europe          28423.0
# 2              Algeria    Africa         449032.0
# 3       American Samoa   Oceania            442.0
# 4              Andorra    Europe            798.0
# ..                 ...       ...              ...
# 229  Wallis and Futuna   Oceania            115.0
# 230     Western Sahara    Africa           5759.0
# 231              Yemen      Asia         336966.0
# 232             Zambia    Africa         200176.0
# 233           Zimbabwe    Africa         163205.0
#
# [234 rows x 3 columns]

# %%
df.groupby('Continent').min()
# group_by_frame
# Out:
#                       Country  2022_Population
# Continent
# Africa                Algeria           1071.0
# Asia              Afghanistan           4490.0
# Europe                Albania              5.0
# North America        Anguilla             43.0
# Oceania        American Samoa             18.0
# South America       Argentina             37.0

# %%
group_by_frame.sum()
# Out:
#                                                          Country  \
# Continent
# Africa         AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...
# Asia           AfghanistanArmeniaAzerbaijanBahrainBangladeshB...
# Europe         AlbaniaAndorraAustriaBelarusBelgiumBosnia and ...
# North America  AnguillaAntigua and BarbudaArubaBahamasBarbado...
# Oceania        American SamoaAustraliaCook IslandsFijiFrench ...
# South America  ArgentinaBoliviaBrazilChileColombiaEcuadorFalk...
#
#                2022_Population
# Continent
# Africa              14255265.0
# Asia                47200394.0
# Europe               7377107.0
# North America        6002940.0
# Oceania               450193.0
# South America        4368159.0

# %%
df.groupby('Continent').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
df.groupby('Continent').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
df.groupby('Base Flavor').sum()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %%
df.groupby('Continent').agg({'Country': ['count'], '2022_Population':['mean','max','count','sum'] })
# Out:
#               Country 2022_Population
#                 count            mean         max count         sum
# Continent
# Africa             57   254558.303571   2185412.0    56  14255265.0
# Asia               50   963273.346939  14258873.0    49  47200394.0
# Europe             50   150553.204082   1447133.0    49   7377107.0
# North America      40   150073.500000   3382898.0    40   6002940.0
# Oceania            23    20463.318182    261774.0    22    450193.0
# South America      14   312011.357143   2153134.0    14   4368159.0

# %%
df.groupby(['Base Flavor','Liked']).agg({'Flavor Rating': ['mean','max','count','sum']})
# Out:
#                   Flavor Rating
#                            mean   max count   sum
# Base Flavor Liked
# Chocolate   Yes             8.4   8.8     3  25.2
# Vanilla     No              3.6   4.7     3  10.8
#             Yes             7.8  10.0     3  23.4

# %%
df.groupby('Continent').describe()
# Out:
#               2022_Population                                                 \
#                         count           mean           std     min       25%
# Continent
# Africa                   56.0  254558.303571  3.777350e+05  1071.0  26144.00
# Asia                     49.0  963273.346939  2.822934e+06  4490.0  54897.00
# Europe                   49.0  150553.204082  2.751315e+05     5.0   6270.00
# North America            40.0  150073.500000  5.641806e+05    43.0    621.75
# Oceania                  22.0   20463.318182  5.874445e+04    18.0    231.25
# South America            14.0  312011.357143  5.572580e+05    37.0  14622.00
#
#
#                     50%        75%         max
# Continent
# Africa         135647.0  304511.50   2185412.0
# Asia           193979.0  518158.00  14258873.0
# Europe          50231.0  104939.00   1447133.0
# North America    2363.5   54696.75   3382898.0
# Oceania          1226.5    3215.75    261774.0
# ...
